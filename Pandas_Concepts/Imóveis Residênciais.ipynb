# %% [markdown]
# # Relatório de Análise III - Imóveis residênciais

# %% [markdown]
# ### Importando o pandas

# %%
import pandas as pd

# %% [markdown]
# ### Importando o Dataset

# %%
dados = pd.read_csv("Dados/aluguel.csv", sep = ';')

# %%
dados.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU
# 0   1700.0       500.0    60.0
# 1   7000.0         NaN     NaN
# 2   5200.0      4020.0  1111.0
# ...

# %% [markdown]
# ### Tratando o DataFrame

# %%
list(dados['Tipo'].drop_duplicates()) #Checa quais tipos de elementos é composta a coluna 'Tipo'
                                      #E coloca em uma lista
# Out:
# ['Quitinete',
#  'Casa',
#  'Conjunto Comercial/Sala',
#  'Apartamento',
#  'Casa de Condomínio',
#  'Prédio Inteiro',
#  'Flat',
#  'Loja/Salão',
#  'Galpão/Depósito/Armazém',
#  'Casa Comercial',
#  'Casa de Vila',
#  'Terreno Padrão',
#  'Box/Garagem',
#  'Loft',
#  'Loja Shopping/ Ct Comercial',
#  'Chácara',
#  'Loteamento/Condomínio',
#  'Sítio',
#  'Pousada/Chalé',
#  'Studio',
#  'Hotel',
#  'Indústria']

# %%
residencial = ['Quitinete',
 'Casa',
 'Apartamento',
 'Casa de Condomínio',
 'Casa de Vila']

# %%
selecao = dados['Tipo'].isin(residencial) #Procura

# %%
selecao.head(10)
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9    False
# Name: Tipo, dtype: bool

# %%
dados_residenciais = dados[selecao]

# %%
dados_residenciais.head(10)
# Out:
#                   Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0            Quitinete       Copacabana        1      0       0    40
# 1                 Casa  Jardim Botânico        2      0       1   100
# 3          Apartamento           Centro        1      0       0    15
# 4          Apartamento     Higienópolis        1      0       0    48
# 5          Apartamento     Vista Alegre        3      1       0    70
# 6          Apartamento         Cachambi        2      0       0    50
# 7   Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8   Casa de Condomínio            Ramos        2      2       0    65
# 10         Apartamento           Centro        1      0       0    36
# 11         Apartamento           Grajaú        2      1       0    70
#
#       Valor  Condominio  IPTU
# 0    1700.0       500.0  60.0
# 1    7000.0         NaN   NaN
# 3     800.0       390.0  20.0
# 4     800.0       230.0   NaN
# 5    1200.0         NaN   NaN
# ...

# %%
dados_residenciais['Tipo'].drop_duplicates()
# Out:
# 0               Quitinete
# 1                    Casa
# 3             Apartamento
# 7      Casa de Condomínio
# 117          Casa de Vila
# Name: Tipo, dtype: object

# %%
dados.shape
# Out:
# (32960, 9)

# %%
dados.shape[0]
# Out:
# 32960

# %%
dados_residenciais.shape[0]
# Out:
# 22580

# %%
dados.shape[0] - dados_residenciais.shape[0]
# Out:
# 10380

# %%
dados_residenciais.head(10)
# Out:
#                   Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0            Quitinete       Copacabana        1      0       0    40
# 1                 Casa  Jardim Botânico        2      0       1   100
# 3          Apartamento           Centro        1      0       0    15
# 4          Apartamento     Higienópolis        1      0       0    48
# 5          Apartamento     Vista Alegre        3      1       0    70
# 6          Apartamento         Cachambi        2      0       0    50
# 7   Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8   Casa de Condomínio            Ramos        2      2       0    65
# 10         Apartamento           Centro        1      0       0    36
# 11         Apartamento           Grajaú        2      1       0    70
#
#       Valor  Condominio  IPTU
# 0    1700.0       500.0  60.0
# 1    7000.0         NaN   NaN
# 3     800.0       390.0  20.0
# 4     800.0       230.0   NaN
# 5    1200.0         NaN   NaN
# ...

# %% [markdown]
# ### Organizando coluna índice

# %%
dados_residenciais.index = range(dados_residenciais.shape[0])

# %%
dados_residenciais.head(10)
# Out:
#                  Tipo           Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0           Quitinete       Copacabana        1      0       0    40   1700.0
# 1                Casa  Jardim Botânico        2      0       1   100   7000.0
# 2         Apartamento           Centro        1      0       0    15    800.0
# 3         Apartamento     Higienópolis        1      0       0    48    800.0
# 4         Apartamento     Vista Alegre        3      1       0    70   1200.0
# 5         Apartamento         Cachambi        2      0       0    50   1300.0
# 6  Casa de Condomínio  Barra da Tijuca        5      4       5   750  22000.0
# 7  Casa de Condomínio            Ramos        2      2       0    65   1000.0
# 8         Apartamento           Centro        1      0       0    36   1200.0
# 9         Apartamento           Grajaú        2      1       0    70   1500.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN
# 2       390.0  20.0
# 3       230.0   NaN
# ...

# %% [markdown]
# ### Exportando a base de dados

# %%
dados_residenciais.to_csv('Dados/dados_residenciais.csv', sep = ';')

# %%
dados_residenciais2 = pd.read_csv('Dados/dados_residenciais.csv', sep = ';')

# %%
dados_residenciais2.head(10)
# Out:
#    Unnamed: 0                Tipo           Bairro  Quartos  Vagas  Suites  \
# 0           0           Quitinete       Copacabana        1      0       0
# 1           1                Casa  Jardim Botânico        2      0       1
# 2           2         Apartamento           Centro        1      0       0
# 3           3         Apartamento     Higienópolis        1      0       0
# 4           4         Apartamento     Vista Alegre        3      1       0
# 5           5         Apartamento         Cachambi        2      0       0
# 6           6  Casa de Condomínio  Barra da Tijuca        5      4       5
# 7           7  Casa de Condomínio            Ramos        2      2       0
# 8           8         Apartamento           Centro        1      0       0
# 9           9         Apartamento           Grajaú        2      1       0
#
#    Area    Valor  Condominio  IPTU
# 0    40   1700.0       500.0  60.0
# 1   100   7000.0         NaN   NaN
# 2    15    800.0       390.0  20.0
# ...

# %% [markdown]
# ### Concertando coluna índice

# %%
dados_residenciais.to_csv('Dados/dados_residenciais.csv', sep = ';', index=False)

# %%
dados_residenciais2 = pd.read_csv('Dados/dados_residenciais.csv', sep = ';')

# %%
dados_residenciais2.head(10)
# Out:
#                  Tipo           Bairro  Quartos  Vagas  Suites  Area    Valor  \
# 0           Quitinete       Copacabana        1      0       0    40   1700.0
# 1                Casa  Jardim Botânico        2      0       1   100   7000.0
# 2         Apartamento           Centro        1      0       0    15    800.0
# 3         Apartamento     Higienópolis        1      0       0    48    800.0
# 4         Apartamento     Vista Alegre        3      1       0    70   1200.0
# 5         Apartamento         Cachambi        2      0       0    50   1300.0
# 6  Casa de Condomínio  Barra da Tijuca        5      4       5   750  22000.0
# 7  Casa de Condomínio            Ramos        2      2       0    65   1000.0
# 8         Apartamento           Centro        1      0       0    36   1200.0
# 9         Apartamento           Grajaú        2      1       0    70   1500.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN
# 2       390.0  20.0
# 3       230.0   NaN
# ...

# %% [markdown]
# ### Ordenando o DataFrame

# %%
dados_residenciais2.sort_values(by = ['Valor', 'Tipo'], inplace = True)

# %%
dados_residenciais2.head(10)
# Out:
#               Tipo                  Bairro  Quartos  Vagas  Suites  Area  \
# 5662   Apartamento              Copacabana        0      0       0    15
# 8905   Apartamento         Barra da Tijuca        0      0       0    15
# 14834  Apartamento                  Leblon        0      0       0    15
# 3701     Quitinete              Copacabana        0      0       0    36
# 5768   Apartamento       Engenho de Dentro        1      0       0    30
# 3748     Quitinete             Jacarepaguá        1      0       0    20
# 17336    Quitinete                    Anil        1      0       0    20
# 1218   Apartamento  Ricardo de Albuquerque        1      0       0    25
# 6757   Apartamento            Campo Grande        1      0       0    21
# 814    Apartamento                 Benfica        1      0       0    15
#
#        Valor  Condominio  IPTU
# 5662   100.0         NaN   NaN
# 8905   100.0         NaN   NaN
# 14834  100.0         1.0   NaN
# 3701   100.0         NaN   NaN
# ...
